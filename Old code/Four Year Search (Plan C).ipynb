# %%
import pandas as pd
import seaborn as sns
import pylab as pl
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv('HIV-Dataset.csv')

# %%
Output = Data[Data['Timestep'] == 0].set_index("PatientID").loc[:, ['Gender', 'Ethnic']]

Output.index = Output.index.map(str) + "_Y1"

# %%
#temp = Data[Data['Timestep'] == 1].set_index("PatientID").drop(['Timestep', 'Gender','Ethnic'], axis=1)
#temp.columns = temp.columns + "_1"

Output = Data[Data['Timestep'] == 0].set_index("PatientID").loc[:, ['Gender', 'Ethnic']]

for i in range(48):
    temp = Data[Data['Timestep'] == i].set_index("PatientID").drop(['Timestep', 'Gender','Ethnic'], axis=1)
    temp.columns = temp.columns + "_" + str(i)
    Output = pd.concat([Output, temp], axis = 1)

Output
# Out:
#            Gender  Ethnic          VL_0        CD4_0  Rel CD4_0  \
# PatientID
# 0             1.0     3.0     29.944271   793.458300  30.834505
# 1             1.0     4.0  31409.234000   215.053470  12.571113
# 2             1.0     3.0  86015.070000  3691.489000  40.247860
# 3             1.0     4.0   2945.257800    87.720314   9.719347
# 4             1.0     4.0  44022.266000   241.410170   7.922622
# ...           ...     ...           ...          ...        ...
# 8911          1.0     4.0  83498.020000  1423.525900  29.719727
# 8912          1.0     4.0    635.776100   269.278380  12.210478
# 8913          2.0     4.0    304.407100   129.897110  25.013070
# 8914          1.0     3.0  34621.406000   929.318850  12.476046
# 8915          1.0     4.0  57102.730000  1937.683800  17.335516
#
#            Base Drug Combo_0  Comp. INI_0  Comp. NNRTI_0  Extra PI_0  \
# PatientID
# 0                        0.0          0.0            3.0         5.0
# ...
